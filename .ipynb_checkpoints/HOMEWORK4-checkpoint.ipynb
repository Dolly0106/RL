# %%
from selenium import webdriver
import time

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service

# 創建一個Service對象並指定chromedriver的路徑
s=Service('D:\\chromedriver\\chromedriver.exe')

# 將Service對象傳遞給webdriver.Chrome()
browser = webdriver.Chrome(service=s)

# %%
#網頁
url = 'https://www.inside.com.tw/'
browser.get(url)
print(browser.page_source)
# Out:
# <html class="off_canvas js-off_canvas"><head prefix="og: http://ogp.me/ns# fb: http://ogp.me/ns/fb# article: http://ogp.me/ns/article#">
#             <meta charset="UTF-8">
#             <meta name="viewport" content="width=device-width, initial-scale=1, shrink-to-fit=no">
#             <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible">
#             <meta http-equiv="Content-Security-Policy" content="block-all-mixed-content">
#             <title>INSIDE - 社群媒體、行動網路、行銷、技術、創業</title>
#             <meta name="HandheldFriendly" content="true">
#             <meta name="MobileOptimized" content="width">
#             <meta name="apple-mobile-web-app-capable" content="yes">
#             <meta name="apple-mobile-web-app-status-bar-style" content="black-translucent">
#
#             <link rel="dns-prefetch" href="//www.inside.com.tw">
#             <link rel="dns-prefetch" href="//www.w3.org">
#             <link rel="dns-prefetch" href="//ogp.me">
#             <link rel="dns-prefetch" href="//www.google-analytics.com">
#             <link rel="dns-prefetch" href="//www.googletagmanager.com">
#             <link rel="dns-prefetch" href="//www.facebook.com">
#
#                             <link rel="canonical" href="https://www.inside.com.tw">
#                                                     <link rel="alternate" hreflang="zh-Hant" href="https://www.inside.com.tw">
#                         <link rel="alternate" type="application/rss+xml" title="INSIDE" hreflang="zh-Hant" href="https://www.inside.com.tw/feed/rss">
#             <meta name="copyright" content="TNL Media Group">
#                         <meta name="description" content="成為科技與商業思維領導媒體，讓讀者掌握最新科技趨勢與商業脈動。">
#             <meta name="keywords" content="社群媒體,行動網路,行銷,技術,創業">
#             <meta name="robots" content="all">
#             <meta property="fb:app_id" content="520754591819646">
#             <meta property="fb:pages" content="159425621565">
#             <meta property="og:type" content="website">
#             <meta property="og:url" content="https://www.inside.com.tw">
#             <meta property="og:site_name" content="INSIDE">
#             <meta property="og:title" content="INSIDE - 社群媒體、行動網路、行銷、技術、創業">
#             <meta property="og:description" content="成為科技與商業思維領導媒體，讓讀者掌握最新科技趨勢與商業脈動。">
#             <meta property="og:image" content="https://www.inside.com.tw/assets/images/default-facebook.jpg">
#                         <meta name="twitter:card" content="summary_large_image">
#             <meta name="twitter:site" content="@insideCyberbuzz">
#             <meta name="twitter:title" content="INSIDE - 社群媒體、行動網路、行銷、技術、創業">
#             <meta name="twitter:description" content="成為科技與商業思維領導媒體，讓讀者掌握最新科技趨勢與商業脈動。">
#             <meta name="twitter:creator" content="@insideCyberbuzz">
#             <meta name="twitter:image" content="https://www.inside.com.tw/assets/images/default-twitter.jpg">
#             <link rel="shortcut icon" href="https://www.inside.com.tw/favicon.ico" type="image/x-icon">
#             <link rel="icon" href="https://www.inside.com.tw/favicon.ico" type="image/x-icon">
#
#             <meta name="theme-color" content="#fffff">
#             <meta name="msapplication-TileColor" content="#fffff">
#             <link rel="stylesheet" href="/assets/css/style.css?id=1a90b648d24f2550c18936a8a03638b4" media="all">
#
#
#             <script src="https://pagead2.googlesyndication.com/pagead/managed/js/adsense/m202312070101/show_ads_impl_fy2021.js" id="google_shimpl"></script><script type="text/javascript" src="//gum.criteo.com/sync?c=72&amp;r=2&amp;j=TRC.getRTUS" charset="UTF-8" async="async"></script><script async="" defer="" src="https://content.ad2iction.com/lo/cdp/ad2tracker.min.js"></script><script type="text/javascript" async="" src="https://cdn.lndata.com/collect.js"></script><script charset="UTF-8" type="text/javascript" src="https://cdn.taboola.com/libtrc/impl.20231218-17_b5-PR-64776-DEV-149593-trecs-ms3-feed-is-overridden-by-placement-with-same-container-1-928c6a6c96c.js"></script><script async="" src="//pm-widget.taboola.com/tnl-inside/load.js"></script><script async="" src="https://ad-specs.guoshipartners.com/static/js/onead-pixel.min.js?_t=5676843"></script><script type="text/javascript" async="" src="https://cdn.lndata.com/collect.js"></script><script async="" src="https://www.googletagmanager.com/gtm.js?id=GTM-M756VB8"></script><script async="" src="//cdn.taboola.com/libtrc/tnl-inside/loader.js" id="tb_loader_script"></script><script src="https://connect.facebook.net/signals/config/664028690679129?v=2.9.138&amp;r=stable&amp;domain=www.inside.com.tw" async=""></script><script async="" src="https://connect.facebook.net/zh_TW/fbevents.js"></script><script async="" src="https://sb.scorecardresearch.com/beacon.js"></script><script async="" src="https://www.googletagmanager.com/gtm.js?id=GTM-5THSZR9&amp;l=DaexGtmDataLayer"></script><script async="" src="https://www.googletagmanager.com/gtm.js?id=GTM-5HRDDHG&amp;l=BrandGtmDataLayer"></script><script type="application/json" id="source-material">{"advertising":0,"cabinet":0,"page":{"key":"index","name":"index"},"terms":[],"authors":[],"infinite":[]}</script>
#
#
# <script async="" src="https://www.googletagmanager.com/gtag/js?id=G-FK4WVJ8FK6&amp;l=ga4DataLayer"></script>
# <script>
#     window.ga4DataLayer = window.ga4DataLayer || [];
#     function ga4_tag(){ga4DataLayer.push(arguments);}
#     // let cmp_data = localStorage.getItem('tnlmediagene-cmp')
#     // if (cmp_data === null) {
#     //     ga4_tag('consent', 'default', {
#     //         'ad_storage': 'denied',
#     //         'analytics_storage': 'denied',
#     //         'functionality_storage': 'denied',
#     //         'personalization_storage': 'denied',
#     //         'security_storage': 'denied'
#     //     });
#     // } else {
#     //     ga4_tag('consent', 'default', JSON.parse(cmp_data))
#     // }
#
#     ga4_tag('js', new Date());
#     ga4_tag('config', 'G-FK4WVJ8FK6');
#     (function () {
#         try {
#             window.Inside = {}
#             if (!window.Inside.sourceMaterial) {
#                 window.Inside.sourceMaterial = JSON.parse(document.getElementById('source-material').textContent)
#             }
#             let source = window.Inside?.sourceMaterial
#             source.authors.forEach(function (value){
#                 ga4_tag('event', 'Counter-Author', {
#                     'action': 'trigger',
#                     'label': value.name
#                 })
#             })
#             source.terms.forEach(function (value){
#                 ga4_tag('event', 'Counter-Term', {
#                     'action': 'trigger',
#                     'label': value.name
#                 })
#             })
#         } catch (e) {}
#     })();
#
#     document.addEventListener("DOMContentLoaded", function() {
#         // ga4 gtm-track
#         var gtmTrack = document.querySelectorAll(".gtm-track");
#         for (var i = 0; i < gtmTrack.length; i++) {
#             gtmTrack[i].addEventListener('click', function(event) {
#                 ga4_tag('event', this.getAttribute('data-gtm-category'), {
#                     'action': 'click',
#                     'label': this.getAttribute('data-gtm-label')
#                 });
#             });
#         }
#     });
# </script>
#
#
# <script>
#     window.BrandGtmDataLayer = window.BrandGtmDataLayer || [];
#     window.DaexGtmDataLayer = window.DaexGtmDataLayer || [];
#     DaexGtmDataLayer.push({'ID' : 'D-100006'});
#
#     (function () {
#         try {
#             let source = window.Inside?.sourceMaterial
#             BrandGtmDataLayer.push({'analyticsAuthors': source.authors})
#             BrandGtmDataLayer.push({'analyticsTerms': source.terms})
#             DaexGtmDataLayer.push({'analyticsAuthors': source.authors})
#             DaexGtmDataLayer.push({'analyticsTerms': source.terms})
#
#
#             //BrandGtmDataLayer.push({'event': 'UserLoaded'})
#             //DaexGtmDataLayer.push({'event': 'UserLoaded'})
#         } catch (e) {}
#     })();
#
#     // BRAND
#     (function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
#         new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
#             j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
# 'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
#     })(window,document,'script','BrandGtmDataLayer','GTM-5HRDDHG');
#     // DAEX
#     (function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
#         new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
#             j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
# 'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
#     })(window,document,'script','DaexGtmDataLayer','GTM-5THSZR9');
#
# </script>
#
#
#
# <script>
#     var _comscore = _comscore || [];
#     _comscore.push({ c1: "2", c2: "17728543" });
#     (function() {
#         var s = document.createElement("script"), el =
#             document.getElementsByTagName("script")[0]; s.async = true;
#         s.src = (document.location.protocol == "https:" ? "https://sb" :
#             "http://b") + ".scorecardresearch.com/beacon.js";
#         el.parentNode.insertBefore(s, el);
#     })();
# </script>
#
#
#
#
# <script>
#     !function(f,b,e,v,n,t,s)
#     {if(f.fbq)return;n=f.fbq=function(){n.callMethod?
#             n.callMethod.apply(n,arguments):n.queue.push(arguments)};
#         if(!f._fbq)f._fbq=n;n.push=n;n.loaded=!0;n.version='2.0';
#         n.queue=[];t=b.createElement(e);t.async=!0;
#         t.src=v;s=b.getElementsByTagName(e)[0];
#         s.parentNode.insertBefore(t,s)}(window, document,'script',
#             'https://connect.facebook.net/zh_TW/fbevents.js');
#     fbq('init', '664028690679129');
#     fbq('track', 'PageView');
# </script>
#
#
#
# <script type="text/javascript">
#     window._taboola = window._taboola || [];
#     _taboola.push({article:'auto'});
#     !function (e, f, u, i) {
#         if (!document.getElementById(i)){
#             e.async = 1;
#             e.src = u;
#             e.id = i;
#             f.parentNode.insertBefore(e, f);
#         }
#     }(document.createElement('script'),
#         document.getElementsByTagName('script')[0],
#         '//cdn.taboola.com/libtrc/tnl-inside/loader.js',
#         'tb_loader_script');
#     if(window.performance && typeof window.performance.mark == 'function')
#     {window.performance.mark('tbl_ic');}
# </script>
#
#
#             <script src="/assets/js/member.js?id=1ddc60a0ea45904ae86bfd6435c73144" async=""></script>
#                         <!--[if lt IE 9]>
#                 <script src="/assets/js/html5shiv.js?id=f4d9dea8e0ae8455500862bbb874d63c" async></script>
#             <![endif]-->
#
#                             <script type="application/ld+json">{"@context":"https:\/\/schema.org","@type":"ItemList","itemListElement":[{"@type":"ListItem","position":1,"description":"\u96fb\u5b50\u90f5\u4ef6\u5b89\u5168\u6027\u548c\u53ef\u4fe1\u5ea6\u63d0\u5347\uff0c\u6253\u9020\u7121\u5783\u573e\u90f5\u4ef6\u7684\u4f7f\u7528\u74b0\u5883\u3002Google \u548c Yahoo \u8fd1\u671f\u5ba3\u5e03\u65b0\u7684\u96fb\u5b50\u90f5\u4ef6\u5bc4\u9001\u898f\u5247\uff0c\u5c07\u65bc 2024 \u5e74 2 \u6708\u751f\u6548\uff0c\u91cd\u9ede\u5728\u65bc\u300c\u8eab\u4efd\u9a57\u8b49\u3001\u5783\u573e\u90f5\u4ef6\u7387\u63a7\u5236\u548c\u7c21\u5316\u7684\u53d6\u6d88\u8a02\u95b1\u6d41\u7a0b\u300d\uff0c\u4ee5\u964d\u4f4e\u5783\u573e\u90f5\u4ef6\u6bd4\u4f8b\u4e26\u63d0\u9ad8\u6536\u4ef6\u5323\u7684\u5b89\u5168\u6027\u3002","image":{"@type":"ImageObject","contentUrl":"https:\/\/bucket-img.tnlmedia.com\/cabinet\/2023\/12\/23b75c7a-d539-4359-9e77-8a6ca9c7083c.png"},"name":"\u5c0f\u5fc3\u8b8a\u6210\u5783\u573e\u4fe1\uff012024 \u5e74 Google \u548c Yahoo \u5ba3\u5e03\u65b0 Email \u90f5\u4ef6\u898f\u5247","url":"https:\/\/www.inside.com.tw\/article\/33671-2024-new-gmail-rules"},{"@type":"ListItem","position":2,"description":"Pinkoi \u65bc 2023 \u5e74\u63a8\u51fa\u5168\u7403\u9996\u500b\u91dd\u5c0d\u8a2d\u8a08\u5e2b\u7684\u539f\u751f\u98a8\u683c\u5f0f AI \u6a21\u578b\uff0c\u7a31\u70ba\u300c\u751f\u6d3b\u98a8\u683c\u667a\u6167\u6a21\u578b\u300d\uff0c\u6db5\u84cb\u300c\u500b\u4eba\u5316\u5546\u57ce\u3001\u500b\u4eba\u5316\u884c\u92b7\u3001\u500b\u4eba\u5316\u8de8\u5883\u5e6b\u624b\u300d\uff0c\u76ee\u524d\u5df2\u6210\u529f\u52a9\u63a8\u54c1\u724c\u8a02\u55ae\u6210\u9577 8 \u500d\u3002","image":{"@type":"ImageObject","contentUrl":"https:\/\/bucket-img.tnlmedia.com\/cabinet\/2023\/12\/7e3bf8c8-5c20-4d37-813f-8894d92d15cc.jpg"},"name":"\u54c1\u724c SaaS \u696d\u7e3e\u8d85\u71df\u6536\u4e09\u6210\uff01Pinkoi\uff1a\u4f48\u5c40\u81ea\u5efa AI \u5df2\u6709\u591a\u5e74","url":"https:\/\/www.inside.com.tw\/article\/33670-pinkoi-ai"},{"@type":"ListItem","position":3,"description":"\u70ba\u4ec0\u9ebc\u6700\u8fd1\u7a81\u7136\u6709\u4eba\u958b\u59cb\u7dca\u5f35 Q-Day \u8981\u5230\u4f86\u4e86\uff1f\u9019\u662f\u56e0\u70ba\u6709\u5169\u4ef6\u4e8b\u60c5\u958b\u59cb\u540c\u6642\u5728\u767c\u751f\u3002","image":{"@type":"ImageObject","contentUrl":"https:\/\/bucket-img.tnlmedia.com\/cabinet\/2023\/12\/80697d35-731d-410c-80ad-e393f6e3e482.jpg"},"name":"\u4e00\u6587\u89e3\u91cb\u4ec0\u9ebc\u662f\u300cQ-Day\u300d","url":"https:\/\/www.inside.com.tw\/article\/33655-what-is-q-day"},{"@type":"ListItem","position":4,"description":"\u79d1\u5b78\u5bb6\u5718\u968a\u6210\u529f\u7814\u767c\u51fa\u5ab2\u7f8e\u947d\u77f3\u7684\u8d85\u786c\u7269\u8cea\uff0c\u7531\u78b3\u548c\u6c2e\u7d44\u6210\uff0c\u6bd4\u76ee\u524d\u786c\u5ea6\u50c5\u6b21\u65bc\u947d\u77f3\u7684\u7acb\u65b9\u6c2e\u5316\u787c\u66f4\u5805\u786c\u3002\u9019\u7a2e\u78b3\u6c2e\u5316\u7269\u6709\u671b\u7528\u65bc\u592a\u7a7a\u8239\u3001\u6c7d\u8eca\u5857\u5c64\u3001\u592a\u967d\u80fd\u677f\u7b49\u9818\u57df\uff0c\u5177\u6709\u5ee3\u6cdb\u7684\u61c9\u7528\u524d\u666f\u3002","image":{"@type":"ImageObject","contentUrl":"https:\/\/bucket-img.tnlmedia.com\/cabinet\/2023\/12\/1eb27d16-bcb1-4b2b-a4e7-088fbe4834b8.png"},"name":"\u786c\u5ea6\u5ab2\u7f8e\u947d\u77f3\uff01\u4eba\u9020\u78b3\u6c2e\u5316\u5408\u7269\u554f\u4e16\uff0c\u53ef\u7528\u65bc\u947d\u982d\u3001\u592a\u967d\u80fd\u677f\u3001\u592a\u7a7a\u8239\u5857\u5c64","url":"https:\/\/www.inside.com.tw\/article\/33649-material-toughness"},{"@type":"ListItem","position":5,"description":"\u9019\u662f\u53f0\u7a4d\u96fb\u9996\u6b21\u63d0\u5230 1.4 \u5948\u7c73\u88fd\u7a0b\u7684\u9032\u5ea6\uff0c\u4e5f\u516c\u5e03\u4e86\u5176\u6b63\u5f0f\u540d\u7a31\u3002","image":{"@type":"ImageObject","contentUrl":"https:\/\/bucket-img.tnlmedia.com\/cabinet\/2023\/12\/c94af5e9-4ed3-4a64-9cd0-0257b6487a7e.jpg"},"name":"\u53f0\u7a4d\u96fb\u9996\u6b21\u63d0\u53ca 1.4 \u5948\u7c73\u88fd\u7a0b\u958b\u767c\u9032\u5ea6 ...
#                             <script type="application/ld+json">{"@context":"https:\/\/schema.org","@type":"Organization","legalName":"INSIDE","url":"https:\/\/www.inside.com.tw","logo":"https:\/\/www.inside.com.tw\/assets\/images\/logo.png","contactPoint":{"@type":"ContactPoint","telephone":"+886-2-66385108","contactType":"customer service","areaServed":"TW","availableLanguage":["Chinese","English"]},"sameAs":["https:\/\/www.facebook.com\/cyberbuzz","https:\/\/twitter.com\/insideCyberbuzz","https:\/\/line.me\/ti\/p\/@paq1370n","https:\/\/www.youtube.com\/channel\/UC5MwBnaH11q1nO2r4hiv5BQ","https:\/\/www.instagram.com\/inside.tw\/","https:\/\/zh.wikipedia.org\/wiki\/INSIDE_%E7%A1%AC%E5%A1%9E%E7%9A%84%E7%B6%B2%E8%B7%AF%E8%B6%A8%E5%8B%A2%E8%A7%80%E5%AF%9F"]}</script>
#                             <script type="application/ld+json">{"@context":"https:\/\/schema.org","@type":"WebSite","url":"https:\/\/www.inside.com.tw","potentialAction":{"@type":"SearchAction","target":"https:\/\/www.inside.com.tw\/search\/{search_term_string}","query-input":"required name=search_term_string"}}</script>
#                             <script type="application/ld+json">{"@context":"https:\/\/schema.org","@type":"WebPage","name":"INSIDE - \u793e\u7fa4\u5a92\u9ad4\u3001\u884c\u52d5\u7db2\u8def\u3001\u884c\u92b7\u3001\u6280\u8853\u3001\u5275\u696d","description":"\u6210\u70ba\u79d1\u6280\u8207\u5546\u696d\u601d\u7dad\u9818\u5c0e\u5a92\u9ad4\uff0c\u8b93\u8b80\u8005\u638c\u63e1\u6700\u65b0\u79d1\u6280\u8da8\u52e2\u8207\u5546\u696d\u8108\u52d5\u3002","keywords":["\u793e\u7fa4\u5a92\u9ad4","\u884c\u52d5\u7db2\u8def","\u884c\u92b7","\u6280\u8853","\u5275\u696d"],"dateCreated":"2023-12-20T14:13:35+08:00","dateModified":"2023-12-20T14:13:35+08:00","primaryImageOfPage":{"@type":"ImageObject","contentUrl":"https:\/\/www.inside.com.tw\/assets\/images\/default.jpg"},"breadcrumb":{"@context":"http:\/\/schema.org","@type":"BreadcrumbList","itemListElement":[{"@type":"ListItem","position":1,"item":{"@id":"https:\/\/www.inside.com.tw","name":"INSIDE","url":"https:\/\/www.inside.com.tw"}},{"@type":"ListItem","position":2,"item":{"@id":"https:\/\/www.inside.com.tw","name":"","url":"https:\/\/www.inside.com.tw"}}],"itemListOrder":"Ascending","numberOfItems":2}}</script>
#
#             <script>
#                 (function (w, d, s, l, i) {
#                     w[l] = w[l] || []
#                     w[l].push({
#                         'gtm.start': new Date().getTime(),
#                         event: 'gtm.js'
#                     })
#                     var f = d.getElementsByTagName(s)[0],
#                         j = d.createElement(s),
#                         dl = l != 'dataLayer' ? '&l=' + l : ''
#                     j.async = true
#                     j.src = 'https://www.googletagmanager.com/gtm.js?id=' + i + dl
#                     f.parentNode.insertBefore(j, f)
#                 })(window, document, 'script', 'dataLayer', 'GTM-M756VB8');
#
#             </script>
#
#             <script>
#                 var ln_data_setting = {
#                     account: '3f85070',
#                     domain: 'inside.com.tw',
#                     cm_tid: '4099'
#                 }
#                 var _smq = _smq || []
#                 _smq.push(['_setAccount', ln_data_setting['account'], new Date()])
#                 _smq.push(['_setDomainName', ln_data_setting['domain']])
#                 _smq.push(['pageview']);
#                 (function () {
#                     var sm = document.createElement('script')
#                     sm.type = 'text/javascript'
#                     sm.async = true
#                     sm.src = ('https:' == document.location.protocol ? 'https://' : 'http://') + 'cdn.lndata.com/collect.js'
#                     var s = document.getElementsByTagName('script')[0]
#                     s.parentNode.insertBefore(sm, s)
#                 })()
#             </script>
#
#             <script>
#                 (function () {
#                     var s = document.createElement('script'), el = document.getElementsByTagName('script')[0]
#                     s.async = true
#                     s.src = (document.location.protocol === 'https:' ? 'https:' : 'http:') + '//ad-specs.guoshipartners.com/static/js/onead-pixel.min.js?_t=' + Math.floor((new Date).getTime() / 300000)
#                     el.parentNode.insertBefore(s, el)
#                 })()
#                 var onead_pixel = onead_pixel || []
#             </script>
#
#
#             <script src="https://resource.tnlmediagene.com/assets/v1/js/tnlmedia-header-footer.js" defer=""></script>
#         <meta http-equiv="origin-trial" content=""><script id="adsense-js" src="https://pagead2.googlesyndication.com/pagead/js/adsbygoogle.js" async="" data-ad-client="ca-pub-4618526234247744" data-checked-head="true"></script><meta http-equiv="origin-trial" content=""><script type="text/javascript" async="" src="https://googleads.g.doubleclick.net/pagead/viewthroughconversion/10822017212/?random=1703053079183&amp;cv=11&amp;fst=1703053079183&amp;bg=ffffff&amp;guid=ON&amp;async=1&amp;gtm=45He3bt0v831551683&amp;gcd=11l1l1l1l1&amp;dma=0&amp;u_w=1280&amp;u_h=720&amp;url=https%3A%2F%2Fwww.inside.com.tw%2F&amp;hn=www.googleadservices.com&amp;frm=0&amp;tiba=INSIDE%20-%20%E7%A4%BE%E7%BE%A4%E5%AA%92%E9%AB%94%E3%80%81%E8%A1%8C%E5%8B%95%E7%B6%B2%E8%B7%AF%E3%80%81%E8%A1%8C%E9%8A%B7%E3%80%81%E6%8A%80%E8%A1%93%E3%80%81%E5%89%B5%E6%A5%AD&amp;auid=1114358891.1703053079&amp;uaa=x86&amp;uab=64&amp;uafvl=Not_A%2520Brand%3B8.0.0.0%7CChromium%3B120.0.6099.72%7CGoogle%2520Chrome%3B120.0.6099.72&amp;uamb=0&amp;uap=Windows&amp;uapv=15.0.0&amp;uaw=0&amp;rfmt=3&amp;fmt=4"></script><script type="text/javascript" async="" src="https://googleads.g.doubleclick.net/pagead/viewthroughconversion/935003361/?random=1703053079188&amp;cv=11&amp;fst=1703053079188&amp;bg=ffffff&amp;guid=ON&amp;async=1&amp;gtm=45He3bt0v831551683&amp;gcd=11l1l1l1l1&amp;dma=0&amp;u_w=1280&amp;u_h=720&amp;url=https%3A%2F%2Fwww.inside.com.tw%2F&amp;hn=www.googleadservices.com&amp;frm=0&amp;tiba=INSIDE%20-%20%E7%A4%BE%E7%BE%A4%E5%AA%92%E9%AB%94%E3%80%81%E8%A1%8C%E5%8B%95%E7%B6%B2%E8%B7%AF%E3%80%81%E8%A1%8C%E9%8A%B7%E3%80%81%E6%8A%80%E8%A1%93%E3%80%81%E5%89%B5%E6%A5%AD&amp;auid=1114358891.1703053079&amp;uaa=x86&amp;uab=64&amp;uafvl=Not_A%2520Brand%3B8.0.0.0%7CChromium%3B120.0.6099.72%7CGoogle%2520Chrome%3B120.0.6099.72&amp;uamb=0&amp;uap=Windows&amp;uapv=15.0.0&amp;uaw=0&amp;rfmt=3&amp;fmt=4"></script><script type="text/javascript" src="//pm-widget.taboola.com/tnl-inside/pmk-20220605.3.js" async="" crossorigin="anonymous"></script><meta http-equiv="origin-trial" content=""><meta http-equiv="origin-trial" content=""><meta http-equiv="origin-trial" content=""><meta http-equiv="origin-trial" content=""><style type="text/css"></style><style>
#       .tnlmedia_collapse_open{
#         overflow: hidden;
#         height: 100%;
#       }
#     </style><script id="gpt-js" src="https://securepubads.g.doubleclick.net/tag/js/gpt.js" async=""></script></head>
#                 <body><div class="fixed-header-group-check-dom"></div>
#
#             <noscript>
#                 <iframe src="https://www.googletagmanager.com/ns.html?id=GTM-M756VB8" height="0" width="0" style="display:none;visibility:hidden"></iframe>
#             </noscript>
#             <noscript>
#                 <iframe src="https://www.googletagmanager.com/ns.html?id=GTM-MTDW7N3" height="0" width="0" style="display:none;visibility:hidden"></iframe>
#             </noscript>
#
#
#             <div class="page page-index">
#                                     <nav class="js_nav">
#
#     <!-- Menu group 集團 menu -->
#     <!-- 引入 Menu group 集團 menu -->
#     <tnlmedia-header theme="styleLight" lang="zh-tw" style="height:56px;display: block;"></tnlmedia-header>
#     <!-- TNLMedia header end -->
#
#     <div class="header js_header ">
#         <div class="container">
#             <div class="header_inner">
#                 <div class="logo">
#                     <a href="https://www.inside.com.tw">INSIDE 硬塞的網路趨勢觀察</a>
#                 </div>
#
#                 <div class="menu js_menu_category">
#                     <div role="search" method="get" class="search_form js_header_search_form">
#                         <input class="js-search_input search_input" id="search" placeholder="搜尋" type="text" name="s" value="">
#                         <button class="js-search_submit search_submit icon-search"></button>
#                     </div>
#                     <!-- route -->
#
#                     <ul class="primary_nav">
#                         <li class="primary_nav_item primary_nav_item-dropdown dropdown">
#                             <a class="primary_nav_item_title dropdown_trigger" href="#">報導</a>
#                             <div class="primary_nav_item_content dropdown_content">
#                                                                     <a class="primary_nav_child_item" href="https://www.inside.com.tw/feature/side-chat" target="_self">塞掐 Side Chat：最科技的Podcast節目</a>
#                                                                     <a class="primary_nav_child_item" href="https://www.inside.com.tw/category/trend" target="_self">新聞</a>
#                                                                     <a class="primary_nav_child_item" href="https://www.inside.com.tw/category/headline" target="_self">頭條</a>
#                                                                     <a class="primary_nav_child_item" href="https://www.inside.com.tw/category/breaking" target="_self">快訊</a>
#                                                                     <a class="primary_nav_child_item" href="https://www.inside.com.tw/category/opinion" target="_self">評論</a>
#                                                                     <a class="primary_nav_child_item" href="https://www.inside.com.tw/category/column" target="_self">專欄</a>
#                                                                     <a class="primary_nav_child_item" href="https://www.inside.com.tw/features" target="_self">專題</a>
#                                                                     <a class="primary_nav_child_item" href="https://www.inside.com.tw/category/interview" target="_self">人物專訪</a>
#                                                                     <a class="primary_nav_child_item" href="https://www.inside.com.tw/category/event" target="_self">活動採訪</a>
#                                                                     <a class="primary_nav_child_item" href="https://www.inside.com.tw/category/unboxing" target="_self">產品評測</a>
#                                                             </div>
#                         </li>
#                         <li class="primary_nav_item primary_nav_item-dropdown dropdown">
#                             <a class="primary_nav_item_title dropdown_trigger" href="#">數位轉型</a>
#                             <div class="primary_nav_item_content dropdown_content">
#                                                                     <a class="primary_nav_child_item" href="https://www.inside.com.tw/tag/%E8%B3%87%E5%AE%89" target="_self">資安</a>
#                                                                     <a class="primary_nav_child_item" href="https://www.inside.com.tw/tag/AI" target="_self">AI</a>
#                                                                     <a class="primary_nav_child_item" href="https://www.inside.com.tw/tag/IOT" target="_self">IOT</a>
#                                                                     <a class="primary_nav_child_item" href="https://www.inside.com.tw/tag/5G" target="_self">5G</a>
#                                                                     <a class="primary_nav_child_item" href="https://www.inside.com.tw/tag/%E9%9B%B2%E7%AB%AF" target="_self">雲端</a>
#                                                                     <a class="primary_nav_child_item" href="https://www.inside.com.tw/tag/%E5%8D%80%E5%A1%8A%E9%8F%88" target="_self">區塊鏈</a>
#                                                                     <a class="primary_nav_child_item" href="https://www.inside.com.tw/tag/%E8%83%BD%E6%BA%90" target="_self">能源科技</a>
#                                                                     <a class="primary_nav_child_item" href="https://www.inside.com.tw/tag/%E9%87%8F%E5%AD%90" target="_self">量子運算</a>
#                                                             </div>
#                         </li>
#                         <li class="primary_nav_item primary_nav_item-dropdown dropdown">
#                             <a class="primary_nav_item_title dropdown_trigger" href="#">半導體</a>
#                             <div class="primary_nav_item_content dropdown_content">
#                                                                     <a class="primary_nav_child_item" href="https://www.inside.com.tw/tag/%E5%8F%B0%E7%A9%8D%E9%9B%BB" target="_self">台積電</a>
#                                                                     <a class="primary_nav_child_item" href="https://www.inside.com.tw/tag/%E8%81%AF%E9%9B%BB" target="_self">聯電</a>
#                                                                     <a class="primary_nav_child_item" href="https://www.inside.com.tw/tag/%E8%81%AF%E7%99%BC%E7%A7%91" target="_self">聯發科</a>
#                                                                     <a class="primary_nav_child_item" href="https://www.inside.com.tw/tag/%E9%AB%98%E9%80%9A" target="_self">高通</a>
#                                                                     <a class="primary_nav_child_item" href="https://www.inside.com.tw/tag/ASML" target="_self">ASML</a>
#                                                                     <a class="primary_nav_child_item" href="https://www.inside.com.tw/tag/AMD" target="_self">AMD</a>
#                                                                     <a class="primary_nav_child_item" href="https://www.inside.com.tw/tag/Intel" target="_self">Intel</a>
#                                                                     <a class="primary_nav_child_item" href="https://www.inside.com.tw/tag/NVIDIA" target="_self">NVIDIA</a>
#                                                             </div>
#                         </li>
#                         <li class="primary_nav_item primary_nav_item-dropdown dropdown">
#                             <a class="primary_nav_item_title dropdown_trigger" href="#">網路</a>
#                             <div class="primary_nav_item_content dropdown_content">
#                                                                     <a class="primary_nav_child_item" href="https://www.inside.com.tw/tag/Apple" target="_self">Apple</a>
#                                                                     <a class="primary_nav_child_item" href="https://www.inside.com.tw/tag/Amazon" target="_self">Amazon</a>
#                                                                     <a class="primary_nav_child_item" href="https://www.inside.com.tw/tag/Facebook" target="_self">Facebook</a>
#                                                                     <a class="primary_nav_child_item" href="https://www.inside.com.tw/tag/Google" target="_self">Google</a>
#                                                                     <a class="primary_nav_child_item" href="https://www.inside.com.tw/tag/Microsoft" target="_self">Microsoft</a>
#                                                                     <a class="primary_nav_child_item" href="https://www.inside.com.tw/tag/%E9%81%8A%E6%88%B2" target="_self">遊戲</a>
#                                                                     <a class="primary_nav_child_item" href="https://www.inside.com.tw/tag/%E4%B8%B2%E6%B5%81%E5%BD%B1%E9%9F%B3" target="_self">串流</a>
#                                                                     <a class="primary_nav_child_item" href="https://www.inside.com.tw/tag/%E8%A1%8C%E9%8A%B7" target="_self">行銷</a>
#                                                                     <a class="primary_nav_child_item" href="https://www.inside.com.tw/tag/%E7%A4%BE%E7%BE%A4" target="_self">社群</a>
#                                                                     <a class="primary_nav_child_item" href="https://www.inside.com.tw/tag/%E9%9B%BB%E5%95%86" target="_self">電商</a>
#                                                             </div>
#                         </li>
#                         <li class="primary_nav_item primary_nav_item-dropdown dropdown">
#                             <a class="primary_nav_item_title dropdown_trigger" href="#">商業</a>
#                             <div class="primary_nav_item_content dropdown_content">
#                                                                     <a class="primary_nav_child_item" href="https://www.inside.com.tw/tag/%E5%89%B5%E6%A5%AD" target="_self">創業</a>
#                                                                     <a class="primary_nav_child_item" href="https://www.inside.com.tw/tag/%E8%81%B7%E5%A0%B4" target="_self">職場</a>
#                                                                     <a class="primary_nav_child_item" href="https://www.inside.com.tw/tag/%E7%AE%A1%E7%90%86" target="_self">管理</a>
#                                                                     <a class="primary_nav_child_item" href="https://www.inside.com.tw/tag/ESG" target="_self">ESG</a>
#                                                                     <a class="primary_nav_child_item" href="https://www.inside.com.tw/tag/IPO" target="_self">IPO</a>
#                                                                     <a class="primary_nav_child_item" href="https://www.inside.com.tw/tag/%E4%BD%B5%E8%B3%BC" target="_self">併購</a>
#                                                                     <a class="primary_nav_child_item" href="https://www.inside.com.tw/tag/%E5%8B%9F%E8%B3%87" target="_self">募資</a>
#                                                                     <a class="primary_nav_child_item" href="https://www.inside.com.tw/tag/%E8%B2%A1%E5%A0%B1" target="_self">財報</a>
#                                                             </div>
#                         </li>
#                         <li class="primary_nav_item primary_nav_item-dropdown dropdown">
#                             <a class="primary_nav_item_title dropdown_trigger" href="#">焦點</a>
#                             <div class="primary_nav_item_content dropdown_content">
#                                                                     <a class="primary_nav_child_item" href="https://sites.google.com/thenewslens.com/insidepossible/" target="_blank">2023 INSIDE POSSIBLE</a>
#                                                                     <a class="primary_nav_child_item" href="https://www.businessyee.com/" target="_blank">商益：商業是最大的公益</a>
#                                                                     <a class="primary_nav_child_item" href="https://sites.google.com/thenewslens.com/2022inside/" target="_blank">2022 INSIDE 趨勢論壇</a>
#                                                                     <a class="primary_nav_child_item" href="https://www.inside.com.tw/transformation-plus" target="_self">數位轉型普拉斯</a>
#                                                                     <a class="primary_nav_child_item" href="https://www.inside.com.tw/feature/aws-tldg-2020" target="_self">數位轉型思維</a>
#                                                                     <a class="primary_nav_child_item" href="https://www.inside.com.tw/feature/2019aws" target="_self">雲端趨勢服務</a>
#                                                                     <a class="primary_nav_child_item" href="https://www.pressplay.cc/insidexadHub" target="_blank">數位行銷人第一堂必修課</a>
#                                                             </div>
#                         </li>
#                         <li class="primary_nav_item primary_nav_item-dropdown dropdown">
#                             <a class="primary_nav_item_title dropdown_trigger" href="#">會員專屬</a>
#                             <div class="primary_nav_item_content dropdown_content">
#                                                                     <a class="primary_nav_child_item" href="https://www.inside.com.tw/feature/member-exclusive?utm_source=website&amp;utm_medium=Bar" target="_self">會員免費內容</a>
#                                                                     <a class="primary_nav_child_item" href="https://www.inside.com.tw/feature/inside-pay-per-view-project-electric-vehicle?utm_source=INSIDE&amp;utm_medium=Bar" target="_self">電動車大未來</a>
#                                                                     <a class="primary_nav_child_item" href="https://www.inside.com.tw/feature/inside-pay-per-view-digital-transformation?utm_source=INSIDE&amp;utm_medium=Bar" target="_self">數位轉型專刊</a>
#                                                                     <a class="primary_nav_child_item" href="https://www.thenewslens.com/subscription?utm_source=INSIDE&amp;utm_medium=Bar" target="_blank">TNL集團通用｜無廣告體驗</a>
#                                                             </div>
#                         </li>
#                     </ul>
#
#                     <div class="secondary_block">
#                         <div class="header_translation_block" onclick="translatePage()">
#                             <span class="lanText-tw active">繁</span> / <span class="lanText-cn">簡</span>
#                         </div>
#                     </div>
#                 </div>
#                 <div class="dropdown js-check-isDropdown" data-dropdown_content="js_menu_category_mobile">
#                     <button class="menu_btn dropdown_trigger" aria-label="category menu">
#                         <span class="menu_btn_icon"><span></span></span>
#                     </button>
#                     <div class="dropdown_content off_canvas_menu_container js_menu_category_mobile js-off_canvas_menu_container"><div class="menu js_menu_category">
#                     <div role="search" method="get" class="search_form js_header_search_form">
#                         <input class="js-search_input search_input" id="search" placeholder="搜尋" type="text" name="s" value="">
#                         <button class="js-search_submit search_submit icon-search"></button>
#                     </div>
#                     <!-- route -->
#
#                     <ul class="primary_nav">
#                         <li class="primary_nav_item primary_nav_item-dropdown dropdown">
#                             <a class="primary_nav_item_title dropdown_trigger" href="#">報導</a>
#                             <div class="primary_nav_item_content dropdown_content">
#                                                                     <a class="primary_nav_child_item" href="https://www.inside.com.tw/feature/side-chat" target="_self">塞掐 Side Chat：最科技的Podcast節目</a>
#                                                                     <a class="primary_nav_child_item" href="https://www.inside.com.tw/category/trend" target="_self">新聞</a>
#                                                                     <a class="primary_nav_child_item" href="https://www.inside.com.tw/category/headline" target="_self">頭條</a>
#                                                                     <a class="primary_nav_child_item" href="https://www.inside.com.tw/category/breaking" target="_self">快訊</a>
#                                                                     <a class="primary_nav_child_item" href="https://www.inside.com.tw/category/opinion" target="_self">評論</a>
#                                                                     <a class="primary_nav_child_item" href="https://www.inside.com.tw/category/column" target="_self">專欄</a>
#                                                                     <a class="primary_nav_child_item" href="https://www.inside.com.tw/features" target="_self">專題</a>
#                                                                     <a class="primary_nav_child_item" href="https://www.inside.com.tw/category/interview" target="_self">人物專訪</a>
#                                                                     <a class="primary_nav_child_item" href="https://www.inside.com.tw/category/event" target="_self">活動採訪</a>
#                                                                     <a class="primary_nav_child_item" href="https://www.inside.com.tw/category/unboxing" target="_self">產品評測</a>
#                                                             </div>
#                         </li>
#                         <li class="primary_nav_item primary_nav_item-dropdown dropdown">
#                             <a class="primary_nav_item_title dropdown_trigger" href="#">數位轉型</a>
#                             <div class="primary_nav_item_content dropdown_content">
#                                                                     <a class="primary_nav_child_item" href="https://www.inside.com.tw/tag/%E8%B3%87%E5%AE%89" target="_self">資安</a>
#                                                                     <a class="primary_nav_child_item" href="https://www.inside.com.tw/tag/AI" target="_self">AI</a>
#                                                                     <a class="primary_nav_child_item" href="https://www.inside.com.tw/tag/IOT" target="_self">IOT</a>
#                                                                     <a class="primary_nav_child_item" href="https://www.inside.com.tw/tag/5G" target="_self">5G</a>
#                                                                     <a class="primary_nav_child_item" href="https://www.inside.com.tw/tag/%E9%9B%B2%E7%AB%AF" target="_self">雲端</a>
#                                                                     <a class="primary_nav_child_item" href="https://www.inside.com.tw/tag/%E5%8D%80%E5%A1%8A%E9%8F%88" target="_self">區塊鏈</a>
#                                                                     <a class="primary_nav_child_item" href="https://www.inside.com.tw/tag/%E8%83%BD%E6%BA%90" target="_self">能源科技</a>
#                                                                     <a class="primary_nav_child_item" href="https://www.inside.com.tw/tag/%E9%87%8F%E5%AD%90" target="_self">量子運算</a>
#                                                             </div>
#                         </li>
#                         <li class="primary_nav_item primary_nav_item-dropdown dropdown">
#                             <a class="primary_nav_item_title dropdown_trigger" href="#">半導體</a>
#                             <div class="primary_nav_item_content dropdown_content">
#                                                                     <a class="primary_nav_child_item" href="https://www.inside.com.tw/tag/%E5%8F%B0%E7%A9%8D%E9%9B%BB" target="_self">台積電</a>
#                                                                     <a class="primary_nav_child_item" href="https://www.inside.com.tw/tag/%E8%81%AF%E9%9B%BB" target="_self">聯電</a>
#                                                                     <a class="primary_nav_child_item" href="https://www.inside.com.tw/tag/%E8%81%AF%E7%99%BC%E7%A7%91" target="_self">聯發科</a>
#                                                                     <a class="primary_nav_child_item" href="https://www.inside.com.tw/tag/%E9%AB%98%E9%80%9A" target="_self">高通</a>
#                                                                     <a class="primary_nav_child_item" href="https://www.inside.com.tw/tag/ASML" target="_self">ASML</a>
#                                                                     <a class="primary_nav_child_item" href="https://www.inside.com.tw/tag/AMD" target="_self">AMD</a>
#                                                                     <a class="primary_nav_child_item" href="https://www.inside.com.tw/tag/Intel" target="_self">Intel</a>
#                                                                     <a class="primary_nav_child_item" href="https://www.inside.com.tw/tag/NVIDIA" target="_self">NVIDIA</a>
#                                                             </div>
#                         </li>
#                         <li class="primary_nav_item primary_nav_item-dropdown dropdown">
#                             <a class="primary_nav_item_title dropdown_trigger" href="#">網路</a>
#                             <div class="primary_nav_item_content dropdown_content">
#                                                                     <a class="primary_nav_child_item" href="https://www.inside.com.tw/tag/Apple" target="_self">Apple</a>
#                                                                     <a class="primary_nav_child_item" href="https://www.inside.com.tw/tag/Amazon" target="_self">Amazon</a>
#                                                                     <a class="primary_nav_child_item" href="https://www.inside.com.tw/tag/Facebook" target="_self">Facebook</a>
#                                                                     <a class="primary_nav_child_item" href="https://www.inside.com.tw/tag/Google" target="_self">Google</a>
#                                                                     <a class="primary_nav_child_item" href="https://www.inside.com.tw/tag/Microsoft" target="_self">Microsoft</a>
#                                                                     <a class="primary_nav_child_item" href="https://www.inside.com.tw/tag/%E9%81%8A%E6%88%B2" target="_self">遊戲</a>
#                                                                     <a class="primary_nav_child_item" href="https://www.inside.com.tw/tag/%E4%B8%B2%E6%B5%81%E5%BD%B1%E9%9F%B3" target="_self">串流</a>
#                                                                     <a class="primary_nav_child_item" href="https://www.inside.com.tw/tag/%E8%A1%8C%E9%8A%B7" target="_self">行銷</a>
#                                                                     <a class="primary_nav_child_item" href="https://www.inside.com.tw/tag/%E7%A4%BE%E7%BE%A4" target="_self">社群</a>
#                                                                     <a class="primary_nav_child_item" href="https://www.inside.com.tw/tag/%E9%9B%BB%E5%95%86" target="_self">電商</a>
#                                                             </div>
#                         </li>
#                         <li class="primary_nav_item primary_nav_item-dropdown dropdown">
#                             <a class="primary_nav_item_title dropdown_trigger" href="#">商業</a>
#                             <div class="primary_nav_item_content dropdown_content">
#                                                                     <a class="primary_nav_child_item" href="https://www.inside.com.tw/tag/%E5%89%B5%E6%A5%AD" target="_self">創業</a>
#                                                                     <a class="primary_nav_child_item" href="https://www.inside.com.tw/tag/%E8%81%B7%E5%A0%B4" target="_self">職場</a>
#                                                                     <a class="primary_nav_child_item" href="https://www.inside.com.tw/tag/%E7%AE%A1%E7%90%86" target="_self">管理</a>
#                                                                     <a class="primary_nav_child_item" href="https://www.inside.com.tw/tag/ESG" target="_self">ESG</a>
#                                                                     <a class="primary_nav_child_item" href="https://www.inside.com.tw/tag/IPO" target="_self">IPO</a>
#                                                                     <a class="primary_nav_child_item" href="https://www.inside.com.tw/tag/%E4%BD%B5%E8%B3%BC" target="_self">併購</a>
#                                                                     <a class="primary_nav_child_item" href="https://www.inside.com.tw/tag/%E5%8B%9F%E8%B3%87" target="_self">募資</a>
# ...
#                     <h5 class="post_title">
#                         <a class="js-auto_break_title" href="https://www.inside.com.tw/article/30715-Sam-Altman">Sam Altman：走下神壇的 OpenAI 創辦人</a>
#                     </h5>
#                     <ul class="post_meta">
#                         <li class="post_date">
#                             <span>2023/11/18</span>
#                         </li>
#                         <li>
#                                                                                             <a href="https://www.inside.com.tw/author/dylan-yeh" title="Posts by Dylan Yeh" class="author url fn" rel="author">Dylan Yeh</a>
#                                                     </li>
#                         <li>
#                                                                                             <a class="hero_slide_tag" href="https://www.inside.com.tw/tag/1452-Sam%20Altman">Sam Altman</a>
#                                                                                                 、                                                                <a class="hero_slide_tag" href="https://www.inside.com.tw/tag/2724-OpenAI">OpenAI</a>
#                                                                                                 、                                                                <a class="hero_slide_tag" href="https://www.inside.com.tw/tag/10709-Y%20Combinator">Y Combinator</a>
#                                                                                                 、                                                                <a class="hero_slide_tag" href="https://www.inside.com.tw/tag/18917-ChatGPT">ChatGPT</a>
#                                                     </li>
#                     </ul>
#                 </div>
#                             <div class="footer_post_list_item">
#                     <h5 class="post_title">
#                         <a class="js-auto_break_title" href="https://www.inside.com.tw/article/10162-the-guy-who-invented-those-annoying-password-rules-now-regrets-wasting-your-time">15 年前發明煩死人的密碼規則，Bill Burr：抱歉浪費大家時間</a>
#                     </h5>
#                     <ul class="post_meta">
#                         <li class="post_date">
#                             <span>2023/10/19</span>
#                         </li>
#                         <li>
#                                                                                             <a href="https://www.inside.com.tw/author/mia" title="Posts by Mia" class="author url fn" rel="author">Mia</a>
#                                                     </li>
#                         <li>
#                                                                                             <a class="hero_slide_tag" href="https://www.inside.com.tw/tag/2366-%E5%AF%86%E7%A2%BC">密碼</a>
#                                                                                                 、                                                                <a class="hero_slide_tag" href="https://www.inside.com.tw/tag/4329-%E8%A6%8F%E5%89%87">規則</a>
#                                                                                                 、                                                                <a class="hero_slide_tag" href="https://www.inside.com.tw/tag/4330-%E8%A8%AD%E5%AE%9A">設定</a>
#                                                     </li>
#                     </ul>
#                 </div>
#                     </div>
#     </div>
#                             </div>
#
#                         </div>
#
#                         <div class="footer_bottom">
#                             <div class="container">
#                                 <div class="subscribe_block footer_subscribe_block">
#     <div class="subscribe_block_title">訂閱 INSIDE</div>
#     <div class="subscribe_block_description js-auto_break_text">隨時關注最新創業、科技、網路、工作訊息。</div>
#     <div class="subscribe_block_action">
#         <div class="subscribe_block_social_list">
#             <a class="subscribe_block_social_item" href="https://www.facebook.com/cyberbuzz" target="_blank" rel="noopener noreferrer"><i class="fab fa-facebook-f"></i></a>
#             <a class="subscribe_block_social_item icon-twitter" href="https://twitter.com/insideCyberbuzz" target="_blank" rel="noopener noreferrer"></a>
#             <a class="subscribe_block_social_item" href="https://line.me/ti/p/@paq1370n" target="_blank" rel="noopener noreferrer"><i class="fab fa-line"></i></a>
#             <a class="subscribe_block_social_item icon-youtube" href="https://www.youtube.com/channel/UC5MwBnaH11q1nO2r4hiv5BQ?sub_confirmation=1" target="_blank" rel="noopener noreferrer"></a>
#             <a class="subscribe_block_social_item gtm-track" data-gtm-category="Footer" data-gtm-label="Newsletter" rel="nofollow" href="https://www.inside.com.tw/insider/newsletter"><i class="fas fa-envelope"></i></a>
#         </div>
#     </div>
#     <ul class="footer_links">
#         <li>
#             <a href="https://www.tnlmediagene.com/zh-tw/media/inside" target="_blank">關於 INSIDE</a>
#         </li>
#     </ul>
# </div>
# <div class="contactus_block">
#     <span class="contactus_title">聯絡我們</span>
#     <ul>
#         <li><a target="_blank" href="mailto:sales@inside.com.tw">廣告採購、授權詢問、業務相關合作：<span>sales@inside.com.tw</span></a>
#         </li>
#         <li><a target="_blank" href="mailto:partnership@inside.com.tw">非業務相關的行銷合作洽詢：<span>partnership@inside.com.tw</span></a>
#         </li>
#     </ul>
#     <ul>
#         <li><a target="_blank" href="mailto:pr@inside.com.tw">新聞稿、書訊等內容合作：<span>pr@inside.com.tw</span></a>
#         </li>
#         <li><a target="_blank" href="mailto:contact@inside.com.tw">新聞採訪、內容檢舉、投稿發文相關問題：<span>contact@inside.com.tw</span></a>
#         </li>
#     </ul>
# </div>
#                             </div>
#                             <tnlmedia-footer theme="styleLight" lang="zh-tw"></tnlmedia-footer>
#                         </div>
#                     </div>
#                 </footer>
#             </div>
#
#                             <div class="ad-content">
#                     <div class="board board-in_all_bottom_mobile_special board-page board-mobile clearfix gpt-new">
#         <script type="application/json">{"name":"in_all_bottom_mobile_special","size":[],"mapping":[{"screen":[0,0],"list":[[320,100],[1,1]]}],"targeting":{"advertising":"0","cabinet":"0","page_key":"index","page_name":"index","author_key":[],"author_name":[]}}</script>
#     </div>
#                 </div>
#                 <div class="ad-content">
#                     <div class="board board-in_all_float_inner board-page clearfix gpt-new" style="display: none;">
#         <script type="application/json">{"name":"in_all_float_inner","size":[],"mapping":[],"targeting":{"advertising":"0","cabinet":"0","page_key":"index","page_name":"index","author_key":[],"author_name":[]},"type":"oop"}</script>
#     </div>
#                 </div>
#
#
#
#             <script src="/assets/js/vendor/jquery-3.3.1.min.js?id=a09e13ee94d51c524b7e2a728c7d4039"></script><script type="text/javascript" id="">(function(){try{var b=google_tag_manager[google_tag_manager["rm"]["31551683"](11)].dataLayer.name,a=google_tag_manager["rm"]["31551683"](12);for(i=0;i<a.length;i++)window[b].push({event:"analyticsAuthor",eventValue:a[i].name})}catch(c){}})();</script><script type="text/javascript" id="">(function(){try{var b=google_tag_manager[google_tag_manager["rm"]["31551683"](13)].dataLayer.name,a=google_tag_manager["rm"]["31551683"](14);for(i=0;i<a.length;i++)window[b].push({event:"analyticsTerm",eventValue:a[i].name})}catch(c){}})();</script>
#             <script src="/assets/js/photon.min.js?id=beec1a513bd54b8793499bc872d3bac5"></script>
#             <script src="https://s0.wp.com/wp-content/js/devicepx-jetpack.js"></script><script type="text/javascript" id="">(function(){try{var a=google_tag_manager[google_tag_manager["rm"]["31551683"](16)].dataLayer.name;window[a].push({markUserLoaded:1})}catch(b){}})();</script><script type="text/javascript" id="">(function(){try{var a=google_tag_manager[google_tag_manager["rm"]["67057748"](18)].dataLayer.name;window[a].push({flagUserLoaded:1})}catch(b){console.warn("[GTM DaEX] "+b)}})();</script><script type="text/javascript" id="">window.daex=window.daex||function(){(daex.q=daex.q||[]).push([].slice.call(arguments))};(function(){daex("setSiteId","D-100006");daex("setUrl",window.location.href)})();(function(){try{var a=document.title;a=a.split("-");a.pop();a=a.join("-").trim();daex("setTitle",a)}catch(b){console.warn("[GTM DaEX] "+b)}})();(function(){try{var a=[],b=google_tag_manager["rm"]["67057748"](19);for(i=0;i<b.length;i++)a.push(b[i].name);daex("setArticleAuthor",a)}catch(c){console.warn("[GTM DaEX] "+c)}})();
# (function(){try{var a=[],b=[],c=google_tag_manager["rm"]["67057748"](20);for(i=0;i<c.length;i++){var d=Object.assign({type:"",name:""},c[i]);"category"===d.type?a.push(d.name):b.push(d.name)}daex("setArticleCategory",a);daex("setArticleTags",b)}catch(e){console.warn("[GTM DaEX] "+e)}})();(function(){try{var a=google_tag_manager["rm"]["67057748"](21);a&&daex("setCid",a)}catch(b){console.warn("[GTM DaEX] "+b)}})();daex("pageView");</script>
#
# <script type="text/javascript" id="" src="https://t.daexauto.com/daex.min.js"></script><script type="text/javascript" id="">var _smq=_smq||[];_smq.push(["_setAccount","3f85070",new Date]);_smq.push(["_setDomainName","inside.com.tw"]);_smq.push(["pageview"]);(function(){var a=document.createElement("script");a.type="text/javascript";a.async=!0;a.src=("https:"==document.location.protocol?"https://":"http://")+"cdn.lndata.com/collect.js";var b=document.getElementsByTagName("script")[0];b.parentNode.insertBefore(a,b)})();</script>
# <script type="text/javascript" id="">(function(){try{var layer=google_tag_manager[google_tag_manager["rm"]["31551683"](23)].dataLayer.name;var list=google_tag_manager["rm"]["31551683"](24);var smq_action="";for(i=0;i<list.length;i++){switch(list[i].type){case "category":smq_action="type";break;default:smq_action="tag";break}_smq.push(["custom","article",smq_action,list[i].name,,1])}}catch(e){}})();</script><script type="text/javascript" id="">(function(a,b,d,f,c){a.Ad2TrackerObject=c;a[c]=a[c]||function(){(a[c].q=a[c].q||[]).push(arguments)};var e=b.getElementsByTagName(d)[0];b=b.createElement(d);b.async=!0;b.defer=!0;b.src=f;e.parentNode.insertBefore(b,e)})(window,document,"script","https://content.ad2iction.com/lo/cdp/ad2tracker.min.js","atcmd");atcmd("create","7919c81c-09f3-11eb-8e68-f23c9173ed43");
# (function(){var a;(a=location.pathname.match(/\/article\/([0-9]+)-/i))?atcmd("postId",a[1]):(a=location.pathname.match(/\/feature\/[a-z0-9.\-_]+\/([0-9]+)-/i))&&atcmd("postId",a[1])})();</script><script type="text/javascript" id="" src="https://js.adsrvr.org/up_loader.1.1.0.js"></script>
#             <script src="https://stats.wp.com/e-201833.js" async="" defer=""></script>
#             <script src="/assets/js/vendor/hammer.js?id=be1b2b8729357fd2e1495814fc20da06"></script>
#             <script src="/assets/js/vendor/swiper-3-4-2.js?id=ad6513dd0961daf79195ce5d0176d20c"></script><ins class="adsbygoogle adsbygoogle-noablate" data-adsbygoogle-status="done" style="display: none !important;" data-ad-status="unfilled"><div id="aswift_0_host" tabindex="0" title="Advertisement" aria-label="Advertisement" style="border: none; height: 0px; width: 0px; margin: 0px; padding: 0px; position: relative; visibility: visible; background-color: transparent; display: inline-block;"><iframe id="aswift_0" name="aswift_0" style="left:0;position:absolute;top:0;border:0;width:undefinedpx;height:undefinedpx;" sandbox="allow-forms allow-popups allow-popups-to-escape-sandbox allow-same-origin allow-scripts allow-top-navigation-by-user-activation" frameborder="0" marginwidth="0" marginheight="0" vspace="0" hspace="0" allowtransparency="true" scrolling="no" src="https://googleads.g.doubleclick.net/pagead/ads?client=ca-pub-4618526234247744&amp;output=html&amp;adk=1812271804&amp;adf=3025194257&amp;lmt=1703053080&amp;plat=1%3A1024%2C2%3A1024%2C3%3A2162688%2C4%3A2162688%2C9%3A32776%2C16%3A8388608%2C17%3A32%2C24%3A32%2C25%3A32%2C30%3A1048576%2C32%3A32%2C41%3A32%2C42%3A32&amp;format=0x0&amp;url=https%3A%2F%2Fwww.inside.com.tw%2F&amp;ea=0&amp;pra=5&amp;wgl=1&amp;easpi=1&amp;asro=0&amp;asiscm=1&amp;aslmt=0.4&amp;asamt=-1&amp;asedf=0&amp;asefa=1&amp;aseiel=1~2~4~6&amp;aslcwct=150&amp;asacwct=25&amp;uach=WyJXaW5kb3dzIiwiMTUuMC4wIiwieDg2IiwiIiwiMTIwLjAuNjA5OS43MiIsbnVsbCwwLG51bGwsIjY0IixbWyJOb3RfQSBCcmFuZCIsIjguMC4wLjAiXSxbIkNocm9taXVtIiwiMTIwLjAuNjA5OS43MiJdLFsiR29vZ2xlIENocm9tZSIsIjEyMC4wLjYwOTkuNzIiXV0sMF0.&amp;dt=1703053080049&amp;bpp=4&amp;bdt=2119&amp;idt=114&amp;shv=r20231207&amp;mjsv=m202312070101&amp;ptt=9&amp;saldr=aa&amp;abxe=1&amp;nras=1&amp;correlator=3427552370021&amp;frm=20&amp;pv=2&amp;ga_vid=1663099874.1703053079&amp;ga_sid=1703053080&amp;ga_hid=2124771875&amp;ga_fc=1&amp;u_tz=480&amp;u_his=2&amp;u_h=720&amp;u_w=1280&amp;u_ah=672&amp;u_aw=1280&amp;u_cd=24&amp;u_sd=1.5&amp;dmc=8&amp;adx=-12245933&amp;ady=-12245933&amp;biw=1019&amp;bih=516&amp;scr_x=0&amp;scr_y=0&amp;eid=44759875%2C44759926%2C44759837%2C31079980%2C95320870%2C95320884&amp;oid=2&amp;pvsid=3747428237203560&amp;tmod=373754148&amp;uas=0&amp;nvt=1&amp;fsapi=1&amp;fc=1920&amp;brdim=10%2C10%2C10%2C10%2C1280%2C0%2C1050%2C652%2C1036%2C516&amp;vis=1&amp;rsz=%7C%7Cs%7C&amp;abl=NS&amp;fu=32768&amp;bc=31&amp;bz=1.01&amp;psd=W251bGwsbnVsbCxudWxsLDNd&amp;ifi=1&amp;uci=a!1&amp;fsb=1&amp;dtd=137" data-google-container-id="a!1" data-load-complete="true"></iframe></div></ins>
#             <script src="/assets/js/vendor/sharer.min.js?id=9c17fd8602aab18b8337139614a30fda"></script>
#
#
#             <script type="text/javascript" src="/assets/js/brand/global.js?id=cc530baf0ec46a031e981744244dc25c"></script>
# <script type="text/javascript" id="">ttd_dom_ready(function(){if("function"===typeof TTDUniversalPixelApi){var a=new TTDUniversalPixelApi;a.init("uvju8zu",["zwc34rp"],"https://insight.adsrvr.org/track/up")}});</script>
#             <script type="text/javascript" src="/assets/js/brand/off-canvas.js?id=81103ab97043ee59fd2382c1bb0fedcd"></script>
#             <script type="text/javascript" src="/assets/js/brand/dropdown.js?id=148555534d145bed7cc2133b31f2e1f4"></script>
#             <script type="text/javascript" src="/assets/js/brand/post-sticky.js?id=23a23aa7624acff70a5fcd54db6f7c3d"></script>
#             <script type="text/javascript" src="/assets/js/brand/index-hero.js?id=dddedb727670f5ca37cb47cb5cb2ac65"></script>
#             <script type="text/javascript" src="/assets/js/brand/search.js?id=077402de4dc1ae0a86364a0b6d7e43ae"></script>
#             <script type="text/javascript" src="/assets/js/brand/common.js?id=4502cca296c279fc8e2fc9c7fca00bcd"></script>
#             <script type="text/javascript" src="/assets/js/brand/job.js?id=065c2c62ef8e4330e2d0b1c4af41eed3"></script>
#             <script type="text/javascript" src="/assets/js/brand/toggle-lan.js?id=f8dfaa091d4091880659708cc916d3f7"></script>
#             <script type="text/javascript" src="/assets/js/brand/carousel.js?id=f1e52ba61ba45bc77838b41c238456ae"></script>
#
#
#
# <div style="display: none; visibility: hidden;"><script src="https://ads.icook.tw/91app.js?v2"></script></div><iframe name="ad2tracker-set-udid" src="https://content.ad2iction.com/lo/cdp/ad2tracker.html?ad2udid=6581658b445e41.16266375984c1313473bd7f04fe6b381a0b008e7" style="height: 0px; overflow: hidden; border: 0px; opacity: 0; visibility: hidden; display: none;"></iframe><iframe id="universal_pixel_zwc34rp" height="0" width="0" style="display:none;" src="https://insight.adsrvr.org/track/up?adv=uvju8zu&amp;ref=https%3A%2F%2Fwww.inside.com.tw%2F&amp;upid=zwc34rp&amp;upv=1.1.0" title="TTD Universal Pixel"></iframe></body><iframe id="google_esf" name="google_esf" src="https://googleads.g.doubleclick.net/pagead/html/r20231207/r20190131/zrt_lookup_fy2021.html" style="display: none;"></iframe></html>

# %%
#搜尋
element = browser.find_element(By.XPATH,'/html/body/div[2]/nav/div/div/div/div[3]/button')
element.click()
#搜尋輸入
keyword = ('編碼偏見')
browser.find_element(By.XPATH, '//*[@id="search"]').send_keys(keyword)
#按下搜尋
element = browser.find_element(By.XPATH,'/html/body/div[2]/nav/div/div/div/div[3]/div/div/div[1]/button')
element.click()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 2
#       1 #搜尋
# ----> 2 element = browser.find_element(By.XPATH,'/html/body/div[2]/nav/div/div/div/div[3]/button')
#       3 element.click()
#       4 #搜尋輸入
#
# NameError: name 'By' is not defined
