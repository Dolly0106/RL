# %%
#匯入csv檔案
#臺中市政府警察局112年5月份交通事故資料
import pandas as pd

data1 = pd.read_csv("11205.csv")
data1
# Out:
#           年  月   日   時   分   縣市    區  死  受傷  2-30  ...  車輛撞擊部位其他  肇事因素個別  \
# 0      2023  5   1   0   5  臺中市  西屯區  0   1     0  ...       NaN     8.0
# 1      2023  5   1   0   9  臺中市   北區  0   0     0  ...       NaN    23.0
# 2      2023  5   1   0  10  臺中市  清水區  0   1     0  ...       NaN     6.0
# 3      2023  5   1   0  37  臺中市  西屯區  0   1     0  ...       NaN    43.0
# 4      2023  5   1   0  46  臺中市   東區  0   0     0  ...       NaN    23.0
# ...     ... ..  ..  ..  ..  ...  ... ..  ..   ...  ...       ...     ...
# 11984  2023  5  31  22  50  臺中市  大里區  0   0     0  ...       NaN    16.0
# 11985  2023  5  31  23   1  臺中市  西屯區  0   0     0  ...       NaN    43.0
# 11986  2023  5  31  23   5  臺中市  龍井區  0   1     0  ...       NaN    44.0
# 11987  2023  5  31  23  14  臺中市  太平區  0   0     0  ...       NaN    44.0
# 11988  2023  5  31  23  55  臺中市  北屯區  0   1     0  ...       NaN    23.0
#
#        肇事因素主要 肇事逃逸    職業  旅次目的   車種       GPS緯度      GPS經度  事故類別
# ...

# %%
#臺中市政府警察局112年6月份交通事故資料
data2 = pd.read_csv("11206.csv")
data2
# Out:
#           序號  縣市別代碼        機關代碼            市話            傳真     年  月   日   時  \
# 0          1  66000  387130000C  (04)23274275  (04)23288582  2023  6   1   0
# 1          2  66000  387130000C  (04)23274275  (04)23288582  2023  6   1   0
# 2          3  66000  387130000C  (04)23274275  (04)23288582  2023  6   1   0
# 3          4  66000  387130000C  (04)23274275  (04)23288582  2023  6   1   0
# 4          5  66000  387130000C  (04)23274275  (04)23288582  2023  6   1   1
# ...      ...    ...         ...           ...           ...   ... ..  ..  ..
# 12077  12078  66000  387130000C  (04)23274275  (04)23288582  2023  6  30  22
# 12078  12079  66000  387130000C  (04)23274275  (04)23288582  2023  6  30  22
# 12079  12080  66000  387130000C  (04)23274275  (04)23288582  2023  6  30  23
# 12080  12081  66000  387130000C  (04)23274275  (04)23288582  2023  6  30  23
# 12081  12082  66000  387130000C  (04)23274275  (04)23288582  2023  6  30  23
#
# ...

# %%
#列出子集合
set_data1 = set(data1["車種"])
set_data2 = set(data2["車種"])

# %%
set_data1
# Out:
# {'A01',
#  'A02',
#  'A04',
#  'A05',
#  'A06',
#  'A11',
#  'A12',
#  'A21',
#  'A31',
#  'A32',
#  'A41',
#  'A42',
#  'B01',
#  'B02',
#  'B03',
#  'B11',
#  'B12',
#  'C01',
#  'C02',
#  'C03',
#  'C04',
#  'C05',
#  'D02',
#  'D03',
#  'E03',
#  'E04',
#  'E05',
#  'F01',
#  'F02',
#  'F03',
#  'F06',
#  'G01',
#  'G02',
#  'G03',
#  'G06',
#  'H01',
#  'H02',
#  'H03',
#  nan}

# %%
set_data2
# Out:
# {'A01',
#  'A02',
#  'A04',
#  'A05',
#  'A06',
#  'A11',
#  'A12',
#  'A31',
#  'A32',
#  'A41',
#  'A42',
#  'B01',
#  'B02',
#  'B03',
#  'B11',
#  'B12',
#  'C01',
#  'C02',
#  'C03',
#  'C04',
#  'D03',
#  'E03',
#  'F01',
#  'F02',
#  'F03',
#  'F06',
#  'G02',
#  'G03',
#  'G06',
#  'H01',
#  'H02',
#  'H03',
#  nan}

# %%
(set_data1 | set_data2)
# Out:
# {'A01',
#  'A02',
#  'A04',
#  'A05',
#  'A06',
#  'A11',
#  'A12',
#  'A21',
#  'A31',
#  'A32',
#  'A41',
#  'A42',
#  'B01',
#  'B02',
#  'B03',
#  'B11',
#  'B12',
#  'C01',
#  'C02',
#  'C03',
#  'C04',
#  'C05',
#  'D02',
#  'D03',
#  'E03',
#  'E04',
#  'E05',
#  'F01',
#  'F02',
#  'F03',
#  'F06',
#  'G01',
#  'G02',
#  'G03',
#  'G06',
#  'H01',
#  'H02',
#  'H03',
#  nan}

# %%
#差集
set_data1 - (set_data1 & set_data2)
# Out:
# {'A21', 'C05', 'D02', 'E04', 'E05', 'G01'}
